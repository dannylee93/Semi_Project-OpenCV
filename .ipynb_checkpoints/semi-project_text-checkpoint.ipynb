# %% [markdown]
# ## 자동차 번호판 검출하기

# %%
# 라이브러리 불러오기
import cv2
import matplotlib.pyplot as plt
import glob

import numpy as np
import time

# %%
import datetime
import PIL 
from PIL import Image

# %%
# 전체 이미지 불러올 경로 지정
img_paths = glob.glob('data/img/*.jpg') # glob 함수로 폴더 내 모든 jpg 파일을 불러옴
for img_path in img_paths: # img_paths에서 파일 경로 하나씩 꺼내오기
    img = cv2.imread(img_path) # 해당 경로에 있는 jpg 이미지 불러오기
    
    height, width, channel = img.shape # 뒤에서 쓸 높이, 너비, 채널 변수 설정
    
    # 그레이스케일 적용
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 

    # Thresholding 하기
    blurred = cv2.GaussianBlur(gray, (3,3), 0) # 가우시안 블러링 
    img_th = cv2.adaptiveThreshold(blurred,
                              maxValue=255.0,
                              adaptiveMethod=cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                              thresholdType=cv2.THRESH_BINARY_INV,
                              blockSize=19,
                              C=9) 

    # 해당 이미지의 모든 Contour 검출
    _, cnts, _=cv2.findContours(img_th, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    result = np.zeros((height, width, channel), dtype=np.uint8)
    
    # Contour 그려주기
    cv2.drawContours(result, contours=cnts, contourIdx=-1, color=(255, 0, 255))

    # Contour 사각형 그려주기
    result = np.zeros((height, width, channel), dtype=np.uint8)

    cnts_dict = []

    for cnt in cnts: # Contour 하나씩 꺼내기
        x, y, w, h = cv2.boundingRect(cnt) # 컨투어에 외접한 직사각형 좌표(x, y), 높이, 너비 리턴
        cv2.rectangle(result, pt1=(x, y), pt2=(x+w, y+h), color=(255, 0, 255), thickness=2)
        # 해당 좌표를 따라 사각형 그리기

        cnts_dict.append({
            'contour':cnt,
            'x':x,
            'y':y,
            'w':w,
            'h':h,
            'cx':x + (w/2),
            'cy':y + (h/2)}) # 그려진 사각형들의 컨투어와 좌표를 cnts_dict에 추가

    # 불필요한 contour 솎아내기
    MIN_AREA = 80
    MIN_WIDTH, MIN_HEIGHT = 2, 8
    MIN_RATIO, MAX_RATI0 = 0.25, 1.0

    possible_cnts = []

    cnt = 0
    for d in cnts_dict:
        area = d['w']*d['h']
        ratio = d['w']/d['h']

        if area > MIN_AREA \
        and d['w'] > MIN_WIDTH and d['h'] > MIN_HEIGHT \
        and MIN_RATIO < ratio < MAX_RATI0:
            d['idx'] = cnt
            cnt += 1
            possible_cnts.append(d)

    result = np.zeros((height, width, channel), dtype=np.uint8)

    for d in possible_cnts:
        cv2.rectangle(result, 
                      pt1=(d['x'], d['y']), 
                      pt2=(d['x']+d['w'], d['y']+d['h']),
                      color=(255, 0 , 255),
                      thickness=2)
    
    # 차량 번호판 contour 검출하기
    MAX_DIAG_MULTIPLYER = 5
    MAX_ANGLE_DIFF = 12.0
    MAX_AREA_DIFF = 0.5
    MAX_WIDTH_DIFF = 0.8
    MAX_HEIGHT_DIFF = 0.2
    MIN_N_MATCHED = 3

    def find_chars(cnt_list):
        matched_result_idx = []

        for d1 in cnt_list:
            matched_cnts_idx = []
            for d2 in cnt_list:
                if d1['idx'] == d2['idx']:
                    continue

                dx = abs(d1['cx'] - d2['cx'])
                dy = abs(d1['cy'] - d2['cy'])

                diagonal_length1 = np.sqrt(d1['w']**2 + d1['h']**2)
                distance = np.linalg.norm(np.array([d1['cx'], d1['cy']]) - np.array([d2['cx'], d2['cy']]))
                if dx == 0:
                    angle_diff = 90
                else:
                    angle_diff = np.degrees(np.arctan(dy/dx))

                area_diff = abs(d1['w']*d1['h'] - d2['w']*d2['h']) / (d1['w']*d1['h'])
                width_diff = abs(d1['w'] - d2['w']) / d1['w']
                height_diff = abs(d1['h'] - d2['h']) / d1['h']

                if distance < diagonal_length1 * MAX_DIAG_MULTIPLYER \
                and angle_diff < MAX_ANGLE_DIFF and area_diff < MAX_AREA_DIFF \
                and width_diff < MAX_WIDTH_DIFF and height_diff < MAX_HEIGHT_DIFF:
                    matched_cnts_idx.append(d2['idx'])

            matched_cnts_idx.append(d1['idx'])

            if len(matched_cnts_idx) < MIN_N_MATCHED:
                continue

            matched_result_idx.append(matched_cnts_idx)

            unmatched_cnt_idx = []
            for d4 in cnt_list:
                if d4['idx'] not in matched_cnts_idx:
                    unmatched_cnt_idx.append(d4['idx'])

            unmatched_cnt = np.take(possible_cnts, unmatched_cnt_idx)

            recursive_cnt_list = find_chars(unmatched_cnt)

            for idx in recursive_cnt_list:
                matched_result_idx.append(idx)

            break

        return matched_result_idx

    result_idx = find_chars(possible_cnts)

    matched_result = []
    for idx_list in result_idx:
        matched_result.append(np.take(possible_cnts, idx_list))

    result = np.zeros((height, width, channel), dtype=np.uint8)

    for r in matched_result:
        for d in r:
            cv2.rectangle(result, 
                          pt1=(d['x'], d['y']), 
                          pt2=(d['x']+d['w'], d['y']+d['h']), 
                          color=(255, 0, 255),
                         thickness=2)

    # 차량 번호판 부분만 crop 하기
    PLATE_WIDTH_PADDING = 1.3
    PLATE_HEIGHT_PADDING = 1.5
    MIN_PLATE_RATIO = 3
    MAX_PLATE_RATIO = 10

    plate_imgs = []
    plate_infos = []

    for i, matched_chars in enumerate(matched_result):
        sorted_chars = sorted(matched_chars, key=lambda x:x['cx'])

        plate_cx = (sorted_chars[0]['cx'] + sorted_chars[-1]['cx']) / 2
        plate_cy = (sorted_chars[0]['cy'] + sorted_chars[-1]['cy']) / 2

        plate_width = (sorted_chars[-1]['x'] + sorted_chars[-1]['w'] - sorted_chars[0]['x'])*PLATE_WIDTH_PADDING

        sum_height = 0
        for d in sorted_chars:
            sum_height += d['h']

        plate_height = int(sum_height / len(sorted_chars)*PLATE_HEIGHT_PADDING)

        triangle_height = sorted_chars[-1]['cy'] - sorted_chars[0]['cy']
        triangle_hypotenus = np.linalg.norm(np.array([sorted_chars[0]['cx'], sorted_chars[0]['cy']]) - 
                                           np.array([sorted_chars[-1]['cx'], sorted_chars[-1]['cy']]))

        angle = np.degrees(np.arcsin(triangle_height / triangle_hypotenus))

        rotation_mtrx = cv2.getRotationMatrix2D(center=(plate_cx, plate_cy), angle=angle, scale=1.0)
        img_rotated = cv2.warpAffine(img_th, M=rotation_mtrx, dsize=(width, height))

        img_cropped = cv2.getRectSubPix(img_rotated,
                                       patchSize = (int(plate_width), int(plate_height)), 
                                       center=(int(plate_cx), int(plate_cy))) # img_rotated 대신 img를 넣을 경우 컬러로 검출

        if img_cropped.shape[1] / img_cropped.shape[0] < MIN_PLATE_RATIO \
        or img_cropped.shape[1] / img_cropped.shape[0] < MIN_PLATE_RATIO > MAX_PLATE_RATIO:
            continue

        plate_imgs.append(img_cropped)
        plate_infos.append({
            'x':int(plate_cx - plate_width / 2),
            'y':int(plate_cy - plate_height / 2),
            'w':int(plate_width),
            'h':int(plate_height)})
        
        now = datetime.datetime.now()
        now_str = now.strftime("%H.%M.%S.%f")
        finished = Image.fromarray(img_cropped) # numpy array 자료형을 image 객체로 변환해준다
        finished.save("data/num2/{}.jpg".format(now_str))

# %% [markdown]
# ![result](https://user-images.githubusercontent.com/58945760/72497450-e2740100-386f-11ea-8482-18bae7104d13.png)

# %% [markdown]
# ## 이미지 검색기 만들기

# %%
import glob, cv2, numpy as np

# %%
# 검출한 번호판 이미지로 검색기 돌려보기

detector = cv2.xfeatures2d.SURF_create()
# FLANN_INDEX_LSH = 6
# index_params = {'algorithm' : FLANN_INDEX_LSH, 'table_number' : 6, 'key_size' : 12, 'multi_probe_level' : 1}
# search_params = {'checks': 32}
matcher = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)

def serch(img):
#     gray1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    kp1, desc1 = detector.detectAndCompute(gray1, None)

    results = {}

    img_paths = glob.glob('data/img/*.jpg')
    for img_path in img_paths:
        cars = cv2.imread(img_path)
        cv2.imshow('searching..', cars)
        cv2.waitKey(10)

        gray2 = cv2.cvtColor(cars, cv2.COLOR_BGR2GRAY)
        kp2, desc2 = detector.detectAndCompute(gray2, None)
        matches = matcher.match(desc1, desc2)

        # 매칭 결과를 거리기준 오름차순으로 정렬 ---③
        matches = sorted(matches, key=lambda x:x.distance)

        # 최소 거리 값과 최대 거리 값 확보 ---④
        min_dist, max_dist = matches[0].distance, matches[-1].distance
        # 최소 거리의 20% 지점을 임계점으로 설정 ---⑤
        ratio = 0.2
        good_thresh = (max_dist - min_dist) * ratio + min_dist

        # 임계점 보다 작은 매칭점만 좋은 매칭점으로 분류 ---⑥
        #m.distance 매칭객체의 거리 공통함수부분참조  
        good_matches = [m for m in matches if m.distance < good_thresh]
        
        MIN_MATCH = 10
        if len(good_matches) > MIN_MATCH:
            src_pts = np.float32([kp1[m.queryIdx].pt for m in good_matches])
            dst_pts = np.float32([kp2[m.trainIdx].pt for m in good_matches])
            mtrx, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 5.0)

            accuracy = float(mask.sum()) / mask.size

            results[img_path] = accuracy
 #       cv2.destroyAllWindows('serching..')

    if len(results) > 0 :
        results = sorted([(v, k) for (k, v) in results.items() if v > 0], reverse=True)

        return results

img_test = cv2.imread('data/num2/17.57.40.996459.jpg') # 번호판 이미지를 넣을 때 매칭이 안되는 오류 발생
gray = cv2.cvtColor(img_test, cv2.COLOR_BGR2GRAY)
results = serch(gray)


if type(results) is None :
    print("NO matched cars found")
else:
    for(i, (accuracy, img_path)) in enumerate(results):
        print(i, img_path, accuracy)
        if i == 0:
            cars = cv2.imread(img_path)
            cv2.putText(cars, ("Accuracy:%.2f%%"%(accuracy*100)), (10,100),
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2, cv2.LINE_AA)
cv2.imshow('result', cars)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# 0 data/img\car_plate441.jpg 0.3
# 1 data/img\car_plate445.jpg 0.1702127659574468
# 2 data/img\car_plate444.jpg 0.14285714285714285
# 3 data/img\car_plate442.jpg 0.13157894736842105
# 4 data/img\car_plate457.jpg 0.125
# 5 data/img\car_plate455.jpg 0.12244897959183673
# 6 data/img\car_plate443.jpg 0.1111111111111111
# 7 data/img\car_plate449.jpg 0.1095890410958904
# 8 data/img\car_plate448.jpg 0.09876543209876543
# 9 data/img\car_plate453.jpg 0.0967741935483871
# 10 data/img\car_plate440.jpg 0.08955223880597014
# 11 data/img\car_plate446.jpg 0.08823529411764706
# 12 data/img\car_plate94.jpg 0.08695652173913043
# 13 data/img\car_plate377.jpg 0.08620689655172414
# 14 data/img\car_plate427.jpg 0.08108108108108109
# 15 data/img\car_plate31.jpg 0.0784313725490196
# 16 data/img\car_plate490.jpg 0.07777777777777778
# 17 data/img\car_plate293.jpg 0.0759493670886076
# 18 data/img\car_plate332.jpg 0.07526881720430108
# 19 data/img\car_plate297.jpg 0.07476635514018691
# 20 data/img\car_plate477.jpg 0.07352941176470588
# 21 data/img\car_plate141.jpg 0.07352941176470588
# 22 data/img\car_plate242.jpg 0.07339449541284404
# 23 data/img\car_plate340.jpg 0.07317073170731707
# 24 data/img\car_plate225.jpg 0.07291666666666667
# 25 data/img\car_plate165.jpg 0.07291666666666667
# 26 data/img\car_plate84.jpg 0.07258064516129033
# 27 data/img\car_plate433.jpg 0.07142857142857142
# 28 data/img\car_plate248.jpg 0.07142857142857142
# 29 data/img\car_plate56.jpg 0.0707070707070707
# 30 data/img\car_plate215.jpg 0.06930693069306931
# 31 data/img\car_plate344.jpg 0.06923076923076923
# 32 data/img\car_plate281.jpg 0.06870229007633588
# 33 data/img\car_plate139.jpg 0.06870229007633588
# 34 data/img\car_plate275.jpg 0.06862745098039216
# 35 data/img\car_plate422.jpg 0.06818181818181818
# 36 data/img\car_plate105.jpg 0.0673076923076923
# 37 data/img\car_plate16.jpg 0.06666666666666667
# 38 data/img\car_plate412.jpg 0.06622516556291391
# 39 data/img\car_plate129.jpg 0.06593406593406594
# 40 data/img\car_plate479.jpg 0.06481481481481481
# 41 data/img\car_plate278.jpg 0.06481481481481481
# 42 data/img\car_plate438.jpg 0.06422018348623854
# 43 data/img\car_plate339.jpg 0.064
# 44 data/img\car_plate493.jpg 0.06382978723404255
# 45 data/img\car_plate467.jpg 0.06349206349206349
# 46 data/img\car_plate439.jpg 0.06315789473684211
# 47 data/img\car_plate71.jpg 0.0625
# 48 data/img\car_plate285.jpg 0.0625
# 49 data/img\car_plate118.jpg 0.0625
# 50 data/img\car_plate77.jpg 0.061946902654867256
# 51 data/img\car_plate391.jpg 0.061946902654867256
# 52 data/img\car_plate409.jpg 0.06153846153846154
# 53 data/img\car_plate171.jpg 0.06140350877192982
# 54 data/img\car_plate279.jpg 0.061224489795918366
# 55 data/img\car_plate169.jpg 0.061224489795918366
# 56 data/img\car_plate117.jpg 0.061068702290076333
# 57 data/img\car_plate133.jpg 0.06097560975609756
# 58 data/img\car_plate425.jpg 0.05982905982905983
# 59 data/img\car_plate327.jpg 0.05982905982905983
# 60 data/img\car_plate261.jpg 0.059322033898305086
# 61 data/img\car_plate207.jpg 0.059322033898305086
# 62 data/img\car_plate85.jpg 0.05925925925925926
# 63 data/img\car_plate70.jpg 0.058823529411764705
# 64 data/img\car_plate237.jpg 0.058823529411764705
# 65 data/img\car_plate202.jpg 0.058823529411764705
# 66 data/img\car_plate175.jpg 0.058823529411764705
# 67 data/img\car_plate126.jpg 0.058823529411764705
# 68 data/img\car_plate104.jpg 0.058823529411764705
# 69 data/img\car_plate235.jpg 0.058394160583941604
# 70 data/img\car_plate149.jpg 0.058394160583941604
# 71 data/img\car_plate131.jpg 0.058394160583941604
# 72 data/img\car_plate402.jpg 0.058333333333333334
# 73 data/img\car_plate321.jpg 0.05785123966942149
# 74 data/img\car_plate335.jpg 0.057692307692307696
# 75 data/img\car_plate4.jpg 0.05755395683453238
# 76 data/img\car_plate394.jpg 0.05755395683453238
# 77 data/img\car_plate151.jpg 0.05737704918032787
# 78 data/img\car_plate90.jpg 0.05714285714285714
# 79 data/img\car_plate341.jpg 0.05714285714285714
# 80 data/img\car_plate418.jpg 0.056910569105691054
# 81 data/img\car_plate312.jpg 0.05660377358490566
# 82 data/img\car_plate300.jpg 0.05660377358490566
# 83 data/img\car_plate109.jpg 0.05660377358490566
# 84 data/img\car_plate30.jpg 0.056451612903225805
# 85 data/img\car_plate103.jpg 0.056451612903225805
# 86 data/img\car_plate3.jpg 0.056
# 87 data/img\car_plate119.jpg 0.056
# 88 data/img\car_plate401.jpg 0.055944055944055944
# 89 data/img\car_plate325.jpg 0.055944055944055944
# 90 data/img\car_plate417.jpg 0.05555555555555555
# 91 data/img\car_plate415.jpg 0.05555555555555555
# 92 data/img\car_plate336.jpg 0.05555555555555555
# 93 data/img\car_plate239.jpg 0.05555555555555555
# 94 data/img\car_plate236.jpg 0.05555555555555555
# 95 data/img\car_plate211.jpg 0.05555555555555555
# 96 data/img\car_plate158.jpg 0.05555555555555555
# 97 data/img\car_plate138.jpg 0.05517241379310345
# 98 data/img\car_plate489.jpg 0.05511811023622047
# 99 data/img\car_plate44.jpg 0.05511811023622047
# 100 data/img\car_plate431.jpg 0.05511811023622047
# 101 data/img\car_plate410.jpg 0.05511811023622047
# 102 data/img\car_plate39.jpg 0.05511811023622047
# 103 data/img\car_plate220.jpg 0.05504587155963303
# 104 data/img\car_plate136.jpg 0.054878048780487805
# 105 data/img\car_plate313.jpg 0.0546875
# 106 data/img\car_plate299.jpg 0.0546875
# 107 data/img\car_plate259.jpg 0.0546875
# 108 data/img\car_plate201.jpg 0.0546875
# 109 data/img\car_plate481.jpg 0.05454545454545454
# 281 data/img\car_plate333.jpg 0.041666666666666664
# 282 data/img\car_plate482.jpg 0.04142011834319527
# 283 data/img\car_plate480.jpg 0.04142011834319527
# 284 data/img\car_plate319.jpg 0.04142011834319527
# 285 data/img\car_plate252.jpg 0.04142011834319527
# 286 data/img\car_plate209.jpg 0.041379310344827586
# 287 data/img\car_plate63.jpg 0.041176470588235294
# 288 data/img\car_plate498.jpg 0.041176470588235294
# 289 data/img\car_plate99.jpg 0.04093567251461988
# 290 data/img\car_plate491.jpg 0.040697674418604654
# 291 data/img\car_plate316.jpg 0.040697674418604654
# 292 data/img\car_plate18.jpg 0.040697674418604654
# 293 data/img\car_plate240.jpg 0.04054054054054054
# 294 data/img\car_plate153.jpg 0.04054054054054054
# 295 data/img\car_plate468.jpg 0.04048582995951417
# 296 data/img\car_plate426.jpg 0.04046242774566474
# 297 data/img\car_plate464.jpg 0.040268456375838924
# 298 data/img\car_plate437.jpg 0.040229885057471264
# 299 data/img\car_plate416.jpg 0.040229885057471264
# 300 data/img\car_plate286.jpg 0.04
# 301 data/img\car_plate26.jpg 0.04
# 302 data/img\car_plate222.jpg 0.04
# 303 data/img\car_plate181.jpg 0.04
# 304 data/img\car_plate290.jpg 0.03980099502487562
# 305 data/img\car_plate389.jpg 0.03977272727272727
# 306 data/img\car_plate383.jpg 0.03977272727272727
# 307 data/img\car_plate2.jpg 0.03977272727272727
# 308 data/img\car_plate156.jpg 0.03977272727272727
# 309 data/img\car_plate51.jpg 0.039735099337748346
# 310 data/img\car_plate272.jpg 0.039473684210526314
# 311 data/img\car_plate474.jpg 0.03940886699507389
# 312 data/img\car_plate210.jpg 0.03940886699507389
# 313 data/img\car_plate98.jpg 0.03932584269662921
# 314 data/img\car_plate254.jpg 0.03932584269662921
# 315 data/img\car_plate81.jpg 0.03910614525139665
# 316 data/img\car_plate223.jpg 0.03910614525139665
# 317 data/img\car_plate120.jpg 0.03896103896103896
# 318 data/img\car_plate89.jpg 0.03888888888888889
# 319 data/img\car_plate214.jpg 0.03888888888888889
# 320 data/img\car_plate182.jpg 0.038834951456310676
# 321 data/img\car_plate470.jpg 0.03870967741935484
# 322 data/img\car_plate128.jpg 0.03870967741935484
# 323 data/img\car_plate91.jpg 0.03867403314917127
# 324 data/img\car_plate69.jpg 0.03867403314917127
# 325 data/img\car_plate5.jpg 0.03867403314917127
# 326 data/img\car_plate403.jpg 0.03867403314917127
# 327 data/img\car_plate396.jpg 0.03867403314917127
# 328 data/img\car_plate36.jpg 0.03867403314917127
# 329 data/img\car_plate301.jpg 0.03867403314917127
# 330 data/img\car_plate296.jpg 0.03867403314917127
# 331 data/img\car_plate289.jpg 0.03867403314917127
# 332 data/img\car_plate8.jpg 0.038461538461538464
# 333 data/img\car_plate461.jpg 0.038461538461538464
# 334 data/img\car_plate34.jpg 0.038461538461538464
# 335 data/img\car_plate163.jpg 0.038461538461538464
# 336 data/img\car_plate348.jpg 0.03825136612021858
# 337 data/img\car_plate244.jpg 0.03825136612021858
# 451 data/img\car_plate48.jpg 0.03015075376884422
# 452 data/img\car_plate46.jpg 0.029787234042553193
# 453 data/img\car_plate172.jpg 0.0297029702970297
# 454 data/img\car_plate22.jpg 0.02962962962962963
# 455 data/img\car_plate305.jpg 0.029556650246305417
# 456 data/img\car_plate140.jpg 0.029556650246305417
# 457 data/img\car_plate395.jpg 0.029411764705882353
# 458 data/img\car_plate419.jpg 0.029288702928870293
# 459 data/img\car_plate499.jpg 0.029166666666666667
# 460 data/img\car_plate365.jpg 0.02912621359223301
# 461 data/img\car_plate23.jpg 0.029045643153526972
# 462 data/img\car_plate52.jpg 0.028985507246376812
# 463 data/img\car_plate423.jpg 0.02880658436213992
# 464 data/img\car_plate343.jpg 0.02875399361022364
# 465 data/img\car_plate87.jpg 0.028455284552845527
# 466 data/img\car_plate188.jpg 0.02834008097165992
# 467 data/img\car_plate38.jpg 0.028112449799196786
# 468 data/img\car_plate364.jpg 0.0273972602739726
# 469 data/img\car_plate384.jpg 0.02734375
# 470 data/img\car_plate368.jpg 0.02727272727272727
# 471 data/img\car_plate354.jpg 0.027237354085603113
# 472 data/img\car_plate86.jpg 0.02702702702702703
# 473 data/img\car_plate40.jpg 0.02702702702702703
# 474 data/img\car_plate353.jpg 0.02702702702702703
# 475 data/img\car_plate349.jpg 0.026936026936026935
# 476 data/img\car_plate358.jpg 0.02654867256637168
# 477 data/img\car_plate216.jpg 0.026402640264026403
# 478 data/img\car_plate471.jpg 0.026217228464419477
# 479 data/img\car_plate267.jpg 0.025806451612903226
# 480 data/img\car_plate107.jpg 0.025735294117647058
# 481 data/img\car_plate352.jpg 0.02564102564102564
# 482 data/img\car_plate357.jpg 0.02553191489361702
# 483 data/img\car_plate392.jpg 0.025423728813559324
# 484 data/img\car_plate347.jpg 0.024657534246575342
# 485 data/img\car_plate361.jpg 0.02413793103448276
# 486 data/img\car_plate385.jpg 0.02390438247011952
# 487 data/img\car_plate356.jpg 0.023890784982935155
# 488 data/img\car_plate49.jpg 0.022364217252396165
# 489 data/img\car_plate362.jpg 0.0220125786163522
# 490 data/img\car_plate367.jpg 0.020761245674740483
# 491 data/img\car_plate366.jpg 0.020618556701030927
# 492 data/img\car_plate355.jpg 0.0196078431372549
# 493 data/img\car_plate351.jpg 0.01927710843373494
# 494 data/img\car_plate375.jpg 0.018018018018018018
# 495 data/img\car_plate370.jpg 0.01728395061728395
# 496 data/img\car_plate376.jpg 0.016587677725118485
# 497 data/img\car_plate363.jpg 0.014527845036319613
# 498 data/img\car_plate372.jpg 0.013574660633484163
# 499 data/img\car_plate373.jpg 0.013303769401330377
# 500 data/img\car_plate374.jpg 0.01293103448275862
# 501 data/img\car_plate371.jpg 0.012755102040816327

# %%
# 검출한 번호판 이미지로 검색기 돌려보기((Good match 사용하지 않음)

detector = cv2.xfeatures2d.SURF_create()
# FLANN_INDEX_LSH = 6
# index_params = {'algorithm' : FLANN_INDEX_LSH, 'table_number' : 6, 'key_size' : 12, 'multi_probe_level' : 1}
# search_params = {'checks': 32}
matcher = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)

def serch(img):
#     gray1 = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    kp1, desc1 = detector.detectAndCompute(gray1, None)

    results = {}

    img_paths = glob.glob('data/img/*.jpg')
    for img_path in img_paths:
        cars = cv2.imread(img_path)
        cv2.imshow('searching..', cars)
        cv2.waitKey(5)

        gray2 = cv2.cvtColor(cars, cv2.COLOR_BGR2GRAY)
        kp2, desc2 = detector.detectAndCompute(gray2, None)
        matches = matcher.match(desc1, desc2)

#         # 매칭 결과를 거리기준 오름차순으로 정렬 ---③
#         matches = sorted(matches, key=lambda x:x.distance)

#         # 최소 거리 값과 최대 거리 값 확보 ---④
#         min_dist, max_dist = matches[0].distance, matches[-1].distance
#         # 최소 거리의 20% 지점을 임계점으로 설정 ---⑤
#         ratio = 0.2
#         good_thresh = (max_dist - min_dist) * ratio + min_dist

#         # 임계점 보다 작은 매칭점만 좋은 매칭점으로 분류 ---⑥
#         #m.distance 매칭객체의 거리 공통함수부분참조  
#         good_matches = [m for m in matches if m.distance < good_thresh]
        
        MIN_MATCH = 10
        if len(matches) > MIN_MATCH:
            src_pts = np.float32([kp1[m.queryIdx].pt for m in matches])
            dst_pts = np.float32([kp2[m.trainIdx].pt for m in matches])
            mtrx, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 5.0)

            accuracy = float(mask.sum()) / mask.size

            results[img_path] = accuracy
 #       cv2.destroyAllWindows('serching..')

    if len(results) > 0 :
        results = sorted([(v, k) for (k, v) in results.items() if v > 0], reverse=True)

        return results

img_test = cv2.imread('data/num2/17.57.40.996459.jpg') # 번호판 이미지를 넣을 때 매칭이 안되는 오류 발생
gray = cv2.cvtColor(img_test, cv2.COLOR_BGR2GRAY)
results = serch(gray)


if type(results) is None :
    print("NO matched cars found")
else:
    for(i, (accuracy, img_path)) in enumerate(results):
        print(i, img_path, accuracy)
        if i == 0:
            cars = cv2.imread(img_path)
            cv2.putText(cars, ("Accuracy:%.2f%%"%(accuracy*100)), (10,100),
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2, cv2.LINE_AA)
cv2.imshow('result', cars)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# 0 data/img\car_plate10.jpg 1.0
# 1 data/img\car_plate445.jpg 0.03137254901960784
# 2 data/img\car_plate457.jpg 0.028391167192429023
# 3 data/img\car_plate94.jpg 0.02181818181818182
# 4 data/img\car_plate90.jpg 0.02168021680216802
# 5 data/img\car_plate109.jpg 0.020348837209302327
# 6 data/img\car_plate453.jpg 0.02028397565922921
# 7 data/img\car_plate89.jpg 0.01987577639751553
# 8 data/img\car_plate215.jpg 0.019801980198019802
# 9 data/img\car_plate442.jpg 0.018306636155606407
# 10 data/img\car_plate97.jpg 0.0182328190743338
# 11 data/img\car_plate427.jpg 0.01791044776119403
# 12 data/img\car_plate254.jpg 0.01761252446183953
# 13 data/img\car_plate278.jpg 0.017605633802816902
# 14 data/img\car_plate168.jpg 0.017543859649122806
# 15 data/img\car_plate441.jpg 0.017412935323383085
# 16 data/img\car_plate444.jpg 0.01627906976744186
# 17 data/img\car_plate443.jpg 0.016166281755196306
# 18 data/img\car_plate151.jpg 0.015985790408525755
# 19 data/img\car_plate31.jpg 0.015817223198594025
# 20 data/img\car_plate107.jpg 0.015670910871694418
# 21 data/img\car_plate289.jpg 0.015580736543909348
# 22 data/img\car_plate34.jpg 0.015406162464985995
# 23 data/img\car_plate482.jpg 0.015402843601895734
# 24 data/img\car_plate149.jpg 0.015296367112810707
# 25 data/img\car_plate178.jpg 0.01529051987767584
# 26 data/img\car_plate162.jpg 0.015256588072122053
# 27 data/img\car_plate429.jpg 0.015240328253223915
# 28 data/img\car_plate165.jpg 0.01487603305785124
# 29 data/img\car_plate9.jpg 0.014864864864864866
# 30 data/img\car_plate134.jpg 0.014840182648401826
# 31 data/img\car_plate158.jpg 0.014727540500736377
# 32 data/img\car_plate341.jpg 0.014641288433382138
# 33 data/img\car_plate439.jpg 0.014586709886547812
# 34 data/img\car_plate249.jpg 0.014586709886547812
# 35 data/img\car_plate141.jpg 0.014577259475218658
# 36 data/img\car_plate47.jpg 0.014563106796116505
# 37 data/img\car_plate27.jpg 0.0142602495543672
# 38 data/img\car_plate253.jpg 0.014157014157014158
# 39 data/img\car_plate123.jpg 0.013953488372093023
# 40 data/img\car_plate438.jpg 0.013937282229965157
# 41 data/img\car_plate163.jpg 0.013910355486862442
# 42 data/img\car_plate88.jpg 0.013824884792626729
# 43 data/img\car_plate148.jpg 0.013793103448275862
# 44 data/img\car_plate452.jpg 0.013717421124828532
# 45 data/img\car_plate154.jpg 0.013630731102850062
# 46 data/img\car_plate122.jpg 0.013544018058690745
# 47 data/img\car_plate409.jpg 0.013431013431013432
# 48 data/img\car_plate53.jpg 0.013348164627363738
# 49 data/img\car_plate333.jpg 0.013333333333333334
# 50 data/img\car_plate455.jpg 0.013282732447817837
# 51 data/img\car_plate169.jpg 0.013268998793727383
# 52 data/img\car_plate159.jpg 0.013227513227513227
# 53 data/img\car_plate446.jpg 0.013179571663920923
# 54 data/img\car_plate161.jpg 0.013140604467805518
# 55 data/img\car_plate85.jpg 0.013100436681222707
# 56 data/img\car_plate164.jpg 0.013062409288824383
# 57 data/img\car_plate412.jpg 0.012987012987012988
# 58 data/img\car_plate251.jpg 0.012865497076023392
# 59 data/img\car_plate104.jpg 0.012618296529968454
# 60 data/img\car_plate25.jpg 0.012585812356979404
# 61 data/img\car_plate176.jpg 0.012519561815336464
# 62 data/img\car_plate261.jpg 0.012461059190031152
# 63 data/img\car_plate79.jpg 0.012437810945273632
# 64 data/img\car_plate96.jpg 0.012396694214876033
# 65 data/img\car_plate106.jpg 0.012396694214876033
# 66 data/img\car_plate377.jpg 0.012392755004766444
# 67 data/img\car_plate167.jpg 0.01238390092879257
# 68 data/img\car_plate143.jpg 0.012362637362637362
# 69 data/img\car_plate71.jpg 0.012345679012345678
# 70 data/img\car_plate196.jpg 0.012333965844402278
# 71 data/img\car_plate112.jpg 0.01233183856502242
# 72 data/img\car_plate449.jpg 0.012307692307692308
# 73 data/img\car_plate454.jpg 0.012295081967213115
# 74 data/img\car_plate126.jpg 0.012295081967213115
# 188 data/img\car_plate217.jpg 0.010262257696693273
# 189 data/img\car_plate263.jpg 0.010243277848911651
# 190 data/img\car_plate428.jpg 0.010227272727272727
# 191 data/img\car_plate30.jpg 0.010189228529839884
# 192 data/img\car_plate277.jpg 0.010178117048346057
# 193 data/img\car_plate117.jpg 0.01016260162601626
# 194 data/img\car_plate503.jpg 0.010158013544018058
# 195 data/img\car_plate464.jpg 0.010139416983523447
# 196 data/img\car_plate2.jpg 0.010135135135135136
# 197 data/img\car_plate105.jpg 0.010101010101010102
# 198 data/img\car_plate284.jpg 0.010089686098654708
# 199 data/img\car_plate415.jpg 0.01008827238335435
# 200 data/img\car_plate296.jpg 0.010078387458006719
# 201 data/img\car_plate497.jpg 0.010070493454179255
# 202 data/img\car_plate39.jpg 0.010062893081761006
# 203 data/img\car_plate218.jpg 0.010062893081761006
# 204 data/img\car_plate186.jpg 0.01006036217303823
# 205 data/img\car_plate197.jpg 0.01005586592178771
# 206 data/img\car_plate133.jpg 0.010054844606946984
# 207 data/img\car_plate40.jpg 0.010044642857142858
# 208 data/img\car_plate320.jpg 0.010040160642570281
# 209 data/img\car_plate302.jpg 0.010037641154328732
# 210 data/img\car_plate48.jpg 0.010025062656641603
# 211 data/img\car_plate15.jpg 0.01002227171492205
# 212 data/img\car_plate448.jpg 0.010014306151645207
# 213 data/img\car_plate118.jpg 0.01
# 214 data/img\car_plate245.jpg 0.00999000999000999
# 215 data/img\car_plate490.jpg 0.009987515605493134
# 216 data/img\car_plate271.jpg 0.009987515605493134
# 217 data/img\car_plate335.jpg 0.00997506234413965
# 218 data/img\car_plate413.jpg 0.009972801450589302
# 219 data/img\car_plate404.jpg 0.009950248756218905
# 220 data/img\car_plate470.jpg 0.009933774834437087
# 221 data/img\car_plate70.jpg 0.009930486593843098
# 222 data/img\car_plate200.jpg 0.009925558312655087
# 223 data/img\car_plate76.jpg 0.009915014164305949
# 224 data/img\car_plate346.jpg 0.009911894273127754
# 225 data/img\car_plate171.jpg 0.009900990099009901
# 226 data/img\car_plate119.jpg 0.009900990099009901
# 227 data/img\car_plate274.jpg 0.009888751545117428
# 228 data/img\car_plate177.jpg 0.009888751545117428
# 229 data/img\car_plate495.jpg 0.009874326750448833
# 230 data/img\car_plate477.jpg 0.009868421052631578
# 231 data/img\car_plate250.jpg 0.009846827133479213
# 232 data/img\car_plate311.jpg 0.00984251968503937
# 233 data/img\car_plate150.jpg 0.0098159509202454
# 234 data/img\car_plate293.jpg 0.009768009768009768
# 235 data/img\car_plate28.jpg 0.009761388286334056
# 236 data/img\car_plate36.jpg 0.009708737864077669
# 237 data/img\car_plate11.jpg 0.009696969696969697
# 238 data/img\car_plate425.jpg 0.009689922480620155
# 239 data/img\car_plate381.jpg 0.00968783638320775
# 240 data/img\car_plate483.jpg 0.009656652360515022
# 241 data/img\car_plate310.jpg 0.009635974304068522
# 242 data/img\car_plate313.jpg 0.009626955475330927
# 243 data/img\car_plate324.jpg 0.009615384615384616
# 244 data/img\car_plate272.jpg 0.009592326139088728
# 245 data/img\car_plate240.jpg 0.009584664536741214
# 246 data/img\car_plate338.jpg 0.009580838323353293
# 247 data/img\car_plate191.jpg 0.009575923392612859
# 248 data/img\car_plate270.jpg 0.009564293304994687
# 249 data/img\car_plate410.jpg 0.00954653937947494
# 250 data/img\car_plate128.jpg 0.009533898305084746
# 251 data/img\car_plate29.jpg 0.009523809523809525
# 252 data/img\car_plate137.jpg 0.009523809523809525
# 253 data/img\car_plate18.jpg 0.009510869565217392
# 254 data/img\car_plate273.jpg 0.00949367088607595
# 255 data/img\car_plate269.jpg 0.009489916963226572
# 256 data/img\car_plate160.jpg 0.009467455621301775
# 257 data/img\car_plate248.jpg 0.00946372239747634
# 258 data/img\car_plate157.jpg 0.00946073793755913
# 259 data/img\car_plate242.jpg 0.009446693657219974
# 260 data/img\car_plate467.jpg 0.009445100354191263
# 261 data/img\car_plate211.jpg 0.00944386149003148
# 262 data/img\car_plate69.jpg 0.009433962264150943
# 263 data/img\car_plate502.jpg 0.009433962264150943
# 264 data/img\car_plate108.jpg 0.009433962264150943
# 265 data/img\car_plate288.jpg 0.009424083769633508
# 266 data/img\car_plate146.jpg 0.009422850412249705
# 267 data/img\car_plate486.jpg 0.009421265141318977
# 268 data/img\car_plate44.jpg 0.009384775808133473
# 269 data/img\car_plate145.jpg 0.00936768149882904
# 270 data/img\car_plate228.jpg 0.00935672514619883
# 271 data/img\car_plate396.jpg 0.009355509355509356
# 272 data/img\car_plate206.jpg 0.009345794392523364
# 273 data/img\car_plate202.jpg 0.009345794392523364
# 274 data/img\car_plate331.jpg 0.009313154831199068
# 275 data/img\car_plate327.jpg 0.009302325581395349
# 276 data/img\car_plate267.jpg 0.009287925696594427
# 277 data/img\car_plate305.jpg 0.009280742459396751
# 278 data/img\car_plate339.jpg 0.009271523178807948
# 279 data/img\car_plate500.jpg 0.009268795056642637
# 280 data/img\car_plate343.jpg 0.009268795056642637
# 281 data/img\car_plate317.jpg 0.009259259259259259
# 282 data/img\car_plate292.jpg 0.009259259259259259
# 283 data/img\car_plate60.jpg 0.009249743062692703
# 284 data/img\car_plate268.jpg 0.009237875288683603
# 285 data/img\car_plate460.jpg 0.00922722029988466
# 286 data/img\car_plate258.jpg 0.00922722029988466
# 287 data/img\car_plate135.jpg 0.00922509225092251
# 288 data/img\car_plate140.jpg 0.009221311475409836
# 289 data/img\car_plate62.jpg 0.009211873080859774
# 290 data/img\car_plate41.jpg 0.009211873080859774
# 291 data/img\car_plate14.jpg 0.009205983889528193
# 292 data/img\car_plate238.jpg 0.009202453987730062
# 293 data/img\car_plate51.jpg 0.009195402298850575
# 294 data/img\car_plate406.jpg 0.009195402298850575
# 295 data/img\car_plate451.jpg 0.009184845005740528
# 296 data/img\car_plate57.jpg 0.009183673469387756
# 297 data/img\car_plate64.jpg 0.009182736455463728
# 298 data/img\car_plate260.jpg 0.009174311926605505
# 299 data/img\car_plate466.jpg 0.009155645981688708
# 300 data/img\car_plate387.jpg 0.009146341463414634
# 357 data/img\car_plate418.jpg 0.008663366336633664
# 358 data/img\car_plate378.jpg 0.008658008658008658
# 359 data/img\car_plate436.jpg 0.008648648648648649
# 360 data/img\car_plate58.jpg 0.008629989212513484
# 361 data/img\car_plate92.jpg 0.00862895493767977
# 362 data/img\car_plate212.jpg 0.00862895493767977
# 363 data/img\car_plate319.jpg 0.008602150537634409
# 364 data/img\car_plate291.jpg 0.008583690987124463
# 365 data/img\car_plate42.jpg 0.00857449088960343
# 366 data/img\car_plate432.jpg 0.008571428571428572
# 367 data/img\car_plate243.jpg 0.008555133079847909
# 368 data/img\car_plate125.jpg 0.008537886872998933
# 369 data/img\car_plate447.jpg 0.008528784648187633
# 370 data/img\car_plate303.jpg 0.008522727272727272
# 371 data/img\car_plate181.jpg 0.008519701810436636
# 372 data/img\car_plate300.jpg 0.008483563096500531
# 373 data/img\car_plate280.jpg 0.008465608465608466
# 374 data/img\car_plate224.jpg 0.008456659619450317
# 375 data/img\car_plate287.jpg 0.008447729672650475
# 376 data/img\car_plate102.jpg 0.008429926238145416
# 377 data/img\car_plate329.jpg 0.008383233532934131
# 378 data/img\car_plate52.jpg 0.008376963350785341
# 379 data/img\car_plate388.jpg 0.008372093023255815
# 380 data/img\car_plate498.jpg 0.008368200836820083
# 381 data/img\car_plate77.jpg 0.008359456635318705
# 382 data/img\car_plate192.jpg 0.008359456635318705
# 383 data/img\car_plate22.jpg 0.008325624421831638
# 384 data/img\car_plate283.jpg 0.008324661810613945
# 385 data/img\car_plate26.jpg 0.008324661810613945
# 386 data/img\car_plate462.jpg 0.008302583025830259
# 387 data/img\car_plate130.jpg 0.008294930875576038
# 388 data/img\car_plate298.jpg 0.008293838862559242
# 389 data/img\car_plate229.jpg 0.008273009307135471
# 390 data/img\car_plate67.jpg 0.008264462809917356
# 391 data/img\car_plate234.jpg 0.008264462809917356
# 392 data/img\car_plate74.jpg 0.008213552361396304
# 393 data/img\car_plate23.jpg 0.008211678832116789
# 394 data/img\car_plate309.jpg 0.008205128205128205
# 395 data/img\car_plate129.jpg 0.008205128205128205
# 396 data/img\car_plate13.jpg 0.00816326530612245
# 397 data/img\car_plate414.jpg 0.008146639511201629
# 398 data/img\car_plate166.jpg 0.008146639511201629
# 399 data/img\car_plate72.jpg 0.008130081300813009
# 400 data/img\car_plate114.jpg 0.008130081300813009
# 401 data/img\car_plate100.jpg 0.008100810081008101
# 402 data/img\car_plate393.jpg 0.008093525179856115
# 403 data/img\car_plate239.jpg 0.008093525179856115
# 404 data/img\car_plate225.jpg 0.008093525179856115
# 405 data/img\car_plate463.jpg 0.008092485549132947
# 406 data/img\car_plate411.jpg 0.00808080808080808
# 407 data/img\car_plate397.jpg 0.008064516129032258
# 408 data/img\car_plate6.jpg 0.008035714285714285
# 409 data/img\car_plate391.jpg 0.008035714285714285
# 410 data/img\car_plate266.jpg 0.008016032064128256
# 411 data/img\car_plate204.jpg 0.007992895204262877
# 412 data/img\car_plate499.jpg 0.007992007992007992
# 413 data/img\car_plate390.jpg 0.007990867579908675
# 414 data/img\car_plate184.jpg 0.007976071784646061
# 415 data/img\car_plate416.jpg 0.007922535211267605
# 416 data/img\car_plate1.jpg 0.007900677200902935
# 417 data/img\car_plate431.jpg 0.007881773399014778
# 418 data/img\car_plate489.jpg 0.007874015748031496
# 419 data/img\car_plate120.jpg 0.007866273352999017
# 420 data/img\car_plate222.jpg 0.007858546168958742
# 421 data/img\car_plate421.jpg 0.007853403141361256
# 422 data/img\car_plate63.jpg 0.007835455435847209
# 423 data/img\car_plate235.jpg 0.007835455435847209
# 424 data/img\car_plate8.jpg 0.007827788649706457
# 425 data/img\car_plate185.jpg 0.007827788649706457
# 426 data/img\car_plate407.jpg 0.007820136852394917
# 427 data/img\car_plate472.jpg 0.0078125
# 428 data/img\car_plate91.jpg 0.007782101167315175
# 429 data/img\car_plate227.jpg 0.007766990291262136
# 430 data/img\car_plate49.jpg 0.007759456838021339
# 431 data/img\car_plate174.jpg 0.007759456838021339
# 432 data/img\car_plate487.jpg 0.007722007722007722
# 433 data/img\car_plate179.jpg 0.007712082262210797
# 434 data/img\car_plate307.jpg 0.007707129094412331
# 435 data/img\car_plate223.jpg 0.007692307692307693
# 436 data/img\car_plate182.jpg 0.007662835249042145
# 437 data/img\car_plate420.jpg 0.007640878701050621
# 438 data/img\car_plate468.jpg 0.007619047619047619
# 439 data/img\car_plate476.jpg 0.007611798287345386
# 440 data/img\car_plate246.jpg 0.007568590350047304
# 441 data/img\car_plate183.jpg 0.007540056550424128
# 442 data/img\car_plate369.jpg 0.007525870178739417
# 443 data/img\car_plate233.jpg 0.007518796992481203
# 444 data/img\car_plate61.jpg 0.0075107296137339056
# 445 data/img\car_plate199.jpg 0.007497656982193065
# 446 data/img\car_plate231.jpg 0.007483629560336763
# 447 data/img\car_plate301.jpg 0.007446808510638298
# 448 data/img\car_plate394.jpg 0.007428040854224698
# 449 data/img\car_plate380.jpg 0.007428040854224698
# 450 data/img\car_plate326.jpg 0.007428040854224698
# 451 data/img\car_plate494.jpg 0.0074142724745134385
# 452 data/img\car_plate220.jpg 0.0074142724745134385
# 453 data/img\car_plate473.jpg 0.007399577167019027
# 454 data/img\car_plate318.jpg 0.007386888273314866
# 455 data/img\car_plate403.jpg 0.007373271889400922
# 456 data/img\car_plate294.jpg 0.007352941176470588
# 457 data/img\car_plate485.jpg 0.0073145245559038665
# 458 data/img\car_plate66.jpg 0.0072992700729927005
# 459 data/img\car_plate68.jpg 0.007285974499089253
# 460 data/img\car_plate180.jpg 0.007272727272727273
# 461 data/img\car_plate219.jpg 0.007266121707538601
# 462 data/img\car_plate458.jpg 0.007194244604316547
# 463 data/img\car_plate205.jpg 0.007128309572301426
# 464 data/img\car_plate419.jpg 0.007049345417925478
# 465 data/img\car_plate383.jpg 0.0070140280561122245
# 466 data/img\car_plate257.jpg 0.006944444444444444
# 467 data/img\car_plate357.jpg 0.006902502157031924
# 468 data/img\car_plate349.jpg 0.006902502157031924
# 469 data/img\car_plate479.jpg 0.006896551724137931
# 470 data/img\car_plate73.jpg 0.00686106346483705
# 471 data/img\car_plate353.jpg 0.006796116504854369
# 472 data/img\car_plate209.jpg 0.006745362563237774
# 473 data/img\car_plate364.jpg 0.006741573033707865
# 474 data/img\car_plate252.jpg 0.006493506493506494
# 475 data/img\car_plate360.jpg 0.006430868167202572
# 476 data/img\car_plate395.jpg 0.006404391582799634
# 477 data/img\car_plate362.jpg 0.006304176516942475
# 478 data/img\car_plate351.jpg 0.006263048016701462
# 479 data/img\car_plate367.jpg 0.006129597197898424
# 480 data/img\car_plate361.jpg 0.006074411541381929
# 481 data/img\car_plate368.jpg 0.005747126436781609
# 482 data/img\car_plate354.jpg 0.005689900426742532
# 483 data/img\car_plate385.jpg 0.005604483586869495
# 484 data/img\car_plate365.jpg 0.005595523581135092
# 485 data/img\car_plate392.jpg 0.005536332179930796
# 486 data/img\car_plate352.jpg 0.0053583389149363695
# 487 data/img\car_plate348.jpg 0.0053475935828877
# 488 data/img\car_plate363.jpg 0.00506649778340722
# 489 data/img\car_plate356.jpg 0.005037783375314861
# 490 data/img\car_plate358.jpg 0.005007153075822604
# 491 data/img\car_plate355.jpg 0.004878048780487805
# 492 data/img\car_plate386.jpg 0.004858299595141701
# 493 data/img\car_plate366.jpg 0.004827586206896552
# 494 data/img\car_plate384.jpg 0.0047425474254742545
# 495 data/img\car_plate347.jpg 0.004688546550569324
# 496 data/img\car_plate375.jpg 0.004475703324808184
# 497 data/img\car_plate371.jpg 0.004156769596199525
# 498 data/img\car_plate372.jpg 0.003923766816143498
# 499 data/img\car_plate373.jpg 0.00392156862745098
# 500 data/img\car_plate370.jpg 0.003865979381443299
# 501 data/img\car_plate374.jpg 0.0038293216630196935
# 502 data/img\car_plate376.jpg 0.0034403669724770644

# %% [markdown]
# ## Tesseract로 글자 인식해보기

# %%
import glob
import PIL
import pytesseract

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

print()
img_list = []
number_list = []
error_list = []

img_paths = glob.glob('data/num/*.jpg') # glob 함수로 폴더 내 모든 jpg 파일을 불러옴
for img_path in img_paths: # img_paths에서 파일 경로 하나씩 꺼내오기
    img = cv2.imread(img_path)
    img_list.append(img)
    number = pytesseract.image_to_string(img, lang = 'eng')
    
    if number == '':
        print('차량 번호 인식에 실패했습니다.')
        error_list.append(number)
    
    else:
        print('차량 번호:', number)
        number_list.append(number)
        
    result = len(number_list) / len(img_list)
print()    
print('차량 번호 검출율:', '%.2f'%result)
# Out:
# 차량 번호: \ 4171 NUX
# 차량 번호 인식에 실패했습니다.
# 차량 번호: — 7G62636-TT]
# 차량 번호: (syZtEy-VeE
# 차량 번호: Reel
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Z2G2995-NN]/
# 차량 번호: | 262443-TP |
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 7G? 1908-4
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | 2682424-ByF
# 차량 번호: Pe Cenl eee baN) i
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | -7G2248-EB}
# 차량 번호: 262367-SO0
# 차량 번호: AEE a
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Z2G628298-F
# 차량 번호: wie
#
# e
#
# Evo ath
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Renkse
# 차량 번호 인식에 실패했습니다.
# 차량 번호: ZG2119-FH
# 차량 번호: —7G6#4134-0f
# 차량 번호: | 2G* 568-TM]
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | 7G6%885-PK|
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: \ tem, 1£625670- |
# 차량 번호 인식에 실패했습니다.
# 차량 번호: ids V0be le
# 차량 번호: 762521
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: mC \ Wee ites vada |
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | 7G#400-HZ {i
# 차량 번호: S407
# 차량 번호 인식에 실패했습니다.
# 차량 번호: NG #:179-AC}:
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | ST#317-Ku}
# 차량 번호 인식에 실패했습니다.
# 차량 번호: ror}
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Ry sio
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: S®NZ 1588
# 차량 번호: A
#
# G=900-D0]
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | ZG2415-MA]
# 차량 번호: 5 CVA PLA
# 차량 번호 인식에 실패했습니다.
# 차량 번호: mivecssielen
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 7G#627-EK}!
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Z2G2988-TU}
# 차량 번호 인식에 실패했습니다.
# 차량 번호: x
#
# 394-JU
# 차량 번호 인식에 실패했습니다.
# 차량 번호: TX  crrenf OKK]
# 차량 번호 인식에 실패했습니다.
# 차량 번호: FNG:54 71
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Me
# 차량 번호: LB2VM 427}
# 차량 번호: trace amis
# 차량 번호 인식에 실패했습니다.
# 차량 번호: TRS
# 차량 번호: 325-J-521
# 차량 번호: DAR Sr
# 차량 번호: 43
#
#
#
# )
#
# (a)
# Ker)
# 4
# 차량 번호: | ZG2655-UR]
# 차량 번호: | 762787 1-S}
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | ¥Z80909-MD}
# 차량 번호 인식에 실패했습니다.
# 차량 번호: WrAtkststs7- oy
# 차량 번호 인식에 실패했습니다.
# 차량 번호: WA Ve Z ia
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 9-1-5:
# 차량 번호: Wie ARY 4
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 9ZH-247 6408
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | MA#398-AG]
# 차량 번호: Ree ele
# 차량 번호: BJ2100-EE]
# 차량 번호: an 40%) ny
# 차량 번호: Z0D2539-CH
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: m .4-J 56-4
# 차량 번호 인식에 실패했습니다.
# 차량 번호: _7G#763-VE].
# 차량 번호 인식에 실패했습니다.
# 차량 번호: TERE
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 2G28000-Z}
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Ack:
#
# see val 4
#
# a
# 차량 번호: VES VAL ae
# 차량 번호: 7G 82745-AM}
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 1 SW8771 AE |
# 차량 번호: eae ye
# 차량 번호 인식에 실패했습니다.
# 차량 번호: EYEE Od
# 차량 번호 인식에 실패했습니다.
# 차량 번호: ER EY BS
# 차량 번호: | KA#127-CO}
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: KZ2386-L
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | PU#253-1B}|
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: _VZ2820-DD
# 차량 번호 인식에 실패했습니다.
# 차량 번호: —7G626839:Al
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: (11-6537
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: WAtEy ae we
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: ZG#9492-Z} |
# 차량 번호: 538-E-945 }
# 차량 번호 인식에 실패했습니다.
# 차량 번호: i deeasyien ya |
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 7G#9576-AAI,
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: RSE a!
# 차량 번호: PU#646-D!
# 차량 번호: {|
# > ‘a
# 4
# MM 1
# F| 7]
# y=
#
# iF
#
#
#
# |
# 차량 번호: | RI 2®486-JD]
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | 762 1929-AH|
# 차량 번호: DU #879-BZ}
# 차량 번호: ley ta
# 차량 번호: ele S79 |
# 차량 번호 인식에 실패했습니다.
# 차량 번호: ST2747-EAh—
# 차량 번호: BS vaak
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Ev der- (0:15)
# 차량 번호: —7G6#7640-/
# 차량 번호: ~DA#545-Al
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | 712-J-032|
# 차량 번호 인식에 실패했습니다.
# 차량 번호: epee}
# 차량 번호 인식에 실패했습니다.
# 차량 번호: _DU#732-CHF
# 차량 번호: | RIS365-FNP
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: _RI#982-JF]'
# 차량 번호: _DUs190-CE
# 차량 번호: eer
# 차량 번호: ‘NCERLa
# 차량 번호 인식에 실패했습니다.
# 차량 번호: aZS*#38584
# 차량 번호: MA: 356-M
# 차량 번호: ST#102-EU
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Relck:se10s ae
# 차량 번호: Trees
# 차량 번호: eT eee
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 1 489-T-051
# 차량 번호: Wire w
# 차량 번호: Z2G23227-N}
# 차량 번호 인식에 실패했습니다.
# 차량 번호: CK #237-V
# 차량 번호 인식에 실패했습니다.
# 차량 번호: { B3KF 196 |
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | SBR:
#
# 268-BZ]
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: WAERESED Tif
# 차량 번호: eli ee ec i
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | 812-T-475
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: - 262 1375-C}
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: SCAT ASL LA
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: VU3369-AN]}
# 차량 번호: BK oye
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Weal RY Ae 3
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: n' €:isvon ee)
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: EL else
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: IIKAZAC 1689)
# 차량 번호: | ZG24040-J]
# 차량 번호: dFB3RE 182)
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Tee Sew
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 2G6#2448-D}
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: —§7T2377-1E]
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Aner tru ys
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 267-AD}
# 차량 번호 인식에 실패했습니다.
# 차량 번호: BLESEVAN
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: NS Gphee a
# 차량 번호: a
#
# (hK2570-CO\
# 차량 번호: \ XK2570-CO)
# 차량 번호: Wiiyeiabt
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Ary test T ih
# 차량 번호 인식에 실패했습니다.
# 차량 번호: ~—1G62887-K
# 차량 번호: ZG3094-MM}
# 차량 번호: | 7622751-B}i
# 차량 번호: | ¥22539-AP]
# 차량 번호: 2G28635-TI)
# 차량 번호: ,LUOT?-3IF |
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Witty oe
# 차량 번호: —2708986-CU}
# 차량 번호: EK VIA) i
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Waele
# 차량 번호: 1 SP<GO 65 §
# 차량 번호: 2G27533-AC
# 차량 번호 인식에 실패했습니다.
# 차량 번호: _2G34499-AD}
# 차량 번호: 1G629707-K
# 차량 번호 인식에 실패했습니다.
# 차량 번호: i vaste
# 차량 번호: | DU2748-BH]
# 차량 번호 인식에 실패했습니다.
# 차량 번호: AEN A
# 차량 번호: _2G62855-VT}
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 7G62484-LD]
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: _2ZG68848-KT}}
# 차량 번호: 3ZG2006-AG],
# 차량 번호 인식에 실패했습니다.
# 차량 번호: AER hy ERE
# 차량 번호 인식에 실패했습니다.
# 차량 번호: AER Ke la
# 차량 번호: B?K 8559 |
# 차량 번호: ZG2906-
# 차량 번호: 72G3903-MD}
# 차량 번호: erates: lek ay 8) |
# 차량 번호: | 2G8977-TT]
# 차량 번호: ZG76304-H}
# 차량 번호: LESSEE ee
# 차량 번호: Wir LCyAt:
# 차량 번호: | P722898-A0}
# 차량 번호: eh 2:)-7 eos
# 차량 번호: \ (AR) HW! IMS660-P |]
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: _ 2G%322-BB] |
# 차량 번호: Aer iA 118
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: — 762503 1-AE}
# 차량 번호: —2U2178-U
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | 26296 1-EG)
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Wy ets ei ete ey NaH
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Ry Atheists ey
# 차량 번호: WUC Vere alee
# 차량 번호: ways |
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: PU*660-BU}
# 차량 번호: Sates sith
# 차량 번호 인식에 실패했습니다.
# 차량 번호: PONY aa
# 차량 번호: SPS495 AP |
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 317-J-939
# 차량 번호: *7G3687-NL
# 차량 번호: Rinse
# 차량 번호: 1 LU V5-445 |
# 차량 번호: |TOL?xX€ 803{_
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 956-RZ|!
#
# | 2G295
#
# Ed
# 차량 번호: xIVAE
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: TEEPE KI
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: | 7G2A427-TUE
# 차량 번호: SBAL434DD]
# 차량 번호 인식에 실패했습니다.
# 차량 번호: (ShdtEaiskee 14 o
# 차량 번호: | 76237 1-AK]'
# 차량 번호: aZG#408-00/
# 차량 번호 인식에 실패했습니다.
# 차량 번호: 042-K-729
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: ZG28405-A]
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: \ TSZABITAY
# 차량 번호: PAE KKEOE
# 차량 번호: \\_ [4100-AC}
# 차량 번호 인식에 실패했습니다.
# 차량 번호: yds Hey TSW AIBA
# 차량 번호: 7622328-V
# 차량 번호 인식에 실패했습니다.
# 차량 번호: WEE}
# 차량 번호: Wis Kya)
# 차량 번호 인식에 실패했습니다.
# 차량 번호: oa Sol aaa
# 차량 번호: BSE Yala
# 차량 번호 인식에 실패했습니다.
# 차량 번호: \ 1679807 E)
# 차량 번호 인식에 실패했습니다.
# 차량 번호: ZG
#
# Fed
#
# STeVAa NS
# 차량 번호: ZG2862-NS}
# 차량 번호: 2G63375-
# 차량 번호 인식에 실패했습니다.
# 차량 번호: a 00K) Ee OE YA rhs
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Ata
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: BCU ae-a
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: ocd eer OCW Vee
# 차량 번호: PYAtEesaied
# 차량 번호: | 262128-VIti
# 차량 번호: 2G632563-ACE
# 차량 번호: + 767662-P¥}
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: SESE: |
# 차량 번호: DiEVIVAT4
# 차량 번호 인식에 실패했습니다.
# 차량 번호: eos ee
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: ZG#773-VE] CHROP
# 차량 번호 인식에 실패했습니다.
# 차량 번호: wit
#
# 7949-ADL.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: AtEyALi ee)
# 차량 번호: VU8135-F _
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: _76#301-ZH
# 차량 번호: | Z628258-H]
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호: Acker Tchet eae
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
# 차량 번호 인식에 실패했습니다.
#
# 차량 번호 검출율: 0.50

# %% [markdown]
# ## 매칭점 확인

# %%
# BF + ORB
# 매칭 실패

import cv2, numpy as np

img1 = cv2.imread('data/img/car_plate10.jpg')
img2 = cv2.imread('data/num2/17.57.40.996459.jpg')
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# ORB 서술자 추출기 생성 ---①
detector = cv2.ORB_create()
# 각 영상에 대해 키 포인트와 서술자 추출 ---②
kp1, desc1 = detector.detectAndCompute(gray1, None)
kp2, desc2 = detector.detectAndCompute(gray2, None)

# BFMatcher 생성, Hamming 거리, 상호 체크 ---③
matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
print(matcher)
# 매칭 계산 ---④
matches = matcher.match(desc1, desc2)
# 매칭 결과 그리기 ---⑤
res = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                     flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

cv2.imshow('BFMatcher + ORB', res)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <BFMatcher 000001E9D9DBEB70>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-32-377e294fd02b> in <module>
#      18 print(matcher)
#      19 # 매칭 계산 ---④
# ---> 20 matches = matcher.match(desc1, desc2)
#      21 # 매칭 결과 그리기 ---⑤
#      22 res = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
#
# error: OpenCV(3.4.2) C:\projects\opencv-python\opencv\modules\core\src\batch_distance.cpp:238: error: (-215:Assertion failed) type == src2.type() && src1.cols == src2.cols && (type == 5 || type == 0) in function 'cv::batchDistance'

# %%
# BF + SIFT 
# 매칭 실패

import cv2, numpy as np

img1 = cv2.imread('data/img/car_plate10.jpg')
img2 = cv2.imread('data/num2/17.57.40.996459.jpg')
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

## SIFT 서술자 추출기 생성 ---①
detector = cv2.xfeatures2d.SIFT_create()
# 각 영상에 대해 키 포인트와 서술자 추출 ---②
kp1, desc1 = detector.detectAndCompute(gray1, None)
kp2, desc2 = detector.detectAndCompute(gray2, None)

# BFMatcher 생성, L1 거리, 상호 체크 ---③
matcher = cv2.BFMatcher(cv2.NORM_L1, crossCheck=True)
# 매칭 계산 ---④
matches = matcher.match(desc1, desc2)
# 매칭 결과 그리기 ---⑤
res = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                      flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)
# 결과 출력 
cv2.imshow('BFMatcher + SIFT', res)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# None
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-27-0a74ee1e2095> in <module>
#       7 print(img2)
#       8 gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
# ----> 9 gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
#      10
#      11 ## SIFT 서술자 추출기 생성 ---①
#
# error: OpenCV(3.4.2) c:\projects\opencv-python\opencv\modules\imgproc\src\color.hpp:253: error: (-215:Assertion failed) VScn::contains(scn) && VDcn::contains(dcn) && VDepth::contains(depth) in function 'cv::CvtHelper<struct cv::Set<3,4,-1>,struct cv::Set<1,-1,-1>,struct cv::Set<0,2,5>,2>::CvtHelper'

# %%
# BF + SURF
# 매칭 성공

import cv2
import numpy as np

img1 = cv2.imread('data/img/car_plate10.jpg')
img2 = cv2.imread('data/num/13.43.55.890592.jpg')
img3 = cv2.imread('data/num2/17.57.40.996459.jpg')

gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# SURF 서술자 추출기 생성 ---①
detector = cv2.xfeatures2d.SURF_create()
kp1, desc1 = detector.detectAndCompute(gray1, None)
kp2, desc2 = detector.detectAndCompute(gray2, None)
kp3, desc3 = detector.detectAndCompute(gray3, None)

# BFMatcher 생성, L2 거리, 상호 체크 ---③
matcher = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)

# 매칭 계산 ---④
matches = matcher.match(desc1, desc2)
# 매칭 결과 그리기 ---⑤
res1 = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                     flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

cv2.imshow('BF + SURF1', res1) # 전처리한 이미지 매칭
cv2.waitKey()
cv2.destroyAllWindows()


# 매칭 계산 ---④
matches = matcher.match(desc1, desc3)
# 매칭 결과 그리기 ---⑤
res2 = cv2.drawMatches(img1, kp1, img3, kp3, matches, None, \
                     flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

cv2.imshow('BF + SURF2', res2) # 컬러 이미지 매칭
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# FLNN + SURF
# 매칭 실패

import cv2, numpy as np

img1 = cv2.imread('data/img/car_plate10.jpg')
img2 = cv2.imread('data/num2/17.57.40.996459.jpg')
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# SURF 생성
detector = cv2.xfeatures2d.SURF_create()
# 키 포인트와 서술자 추출
kp1, desc1 = detector.detectAndCompute(gray1, None)
kp2, desc2 = detector.detectAndCompute(gray2, None)

# 인덱스 파라미터와 검색 파라미터 설정 ---①
FLANN_INDEX_KDTREE = 1
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)

# Flann 매처 생성 ---③
matcher = cv2.FlannBasedMatcher(index_params, search_params)
# 매칭 계산 ---④
matches = matcher.match(desc1, desc2)
# 매칭 그리기
res = cv2.drawMatches(img1, kp1, img2, kp2, matches, None, \
                flags=cv2.DRAW_MATCHES_FLAGS_NOT_DRAW_SINGLE_POINTS)

cv2.imshow('Flann + SURF', res)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ## 참고 페이지

# %%
# https://kolikim.tistory.com/44
# https://stackoverflow.com/questions/902761/saving-a-numpy-array-as-an-image/19174800
